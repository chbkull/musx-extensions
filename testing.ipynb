# %%
# %reload_ext autoreload
# %autoreload 2

import musx
import musx_images
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv.imread('images/stream.jpg')
print(img[0, 0])
# Out:
# [242 230 218]

# %%
plt.imshow(img[:,:,::-1])

# %%
plt.imshow(musx_images.load_image(image_path="images/stream.jpg"))
# plt.imshow(fixed_img, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-069d1e771500> in <module>
# ----> 1 plt.imshow(musx_images.load_image(image_path="images/stream.jpg"))
#       2 # plt.imshow(fixed_img, cmap='gray')
#
# AttributeError: module 'musx_images' has no attribute 'load_image'
