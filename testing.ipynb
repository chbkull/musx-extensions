# %%
# %reload_ext autoreload
# %autoreload 2

import musx
import musx_images
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv.imread('images/stream.jpg')
print(img[0, 0])
# Out:
# [242 230 218]

# %%
plt.imshow(img[:,:,::-1])

# %%
img = musx_images.load_image("images/stream.jpg")
converted_img = musx_images.randomize_color_space(img, 1)

musx_images.display_image(converted_img)
# plt.imshow(converted_img, cmap='gray')

# %%
isinstance(converted_img[0,0], np.ndarray)
# Out:
# True

# %%
test = [[0, 1, 2], [3, 4, 5], [6, 7, 8]]
test2 = np.array(test)
test_ind = (2, 2)
print(test2[test_ind])
# Out:
# 8

# %%
gen = musx_images.traversal_2d(converted_img, stop=10, start_x=500, start_y=250, movement=[(1000, 0), (0, -10)])
[next(gen) for _ in range(10)]
# Out:
# [[26, 24, 240],
#  [148, 169, 246],
#  [23, 81, 41],
#  [160, 84, 82],
#  [144, 141, 38],
#  [157, 176, 68],
#  [24, 17, 247],
#  [179, 68, 101],
#  [34, 65, 39],
#  [176, 81, 69]]

# %%
points = []
for _ in range(1000):
    points.append((int(musx.uniran() * converted_img.shape[0]), int(musx.uniran() * converted_img.shape[1])))

musx_images.display_points(converted_img, points)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-118-b73fcbb74032> in <module>
#       4 points = []
#       5 for _ in range(1000):
# ----> 6     points.append(int(musx.uniran() * converted_img.shape[0]), int(musx.uniran() * converted_img.shape[1]))
#       7
#       8 musx_images.display_points(converted_img, points)
#
# TypeError: list.append() takes exactly one argument (2 given)
