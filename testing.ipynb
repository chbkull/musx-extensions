# %%
# %reload_ext autoreload
# %autoreload 2

import musx
import musx_images
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv.imread('images/stream.jpg')
print(img[0, 0])
# Out:
# [242 230 218]

# %%
plt.imshow(img[:,:,::-1])

# %%
img = musx_images.load_image("images/stream.jpg")
converted_img = musx_images.randomize_color_space(img, 1)

musx_images.display_image(converted_img)
# plt.imshow(converted_img, cmap='gray')

# %%
isinstance(converted_img[0,0], np.ndarray)
# Out:
# True

# %%
test = [[0, 1, 2], [3, 4, 5], [6, 7, 8]]
test2 = np.array(test)
test_ind = (2, 2)
print(test2[test_ind])
# Out:
# 8

# %%
gen = musx_images.line_2d(converted_img, stop=1000, start_row=1000, start_col=1000, end_row=2000, end_col=1000)
vals = [x for x in next(gen)]
print(vals)
data, pts = zip(*vals)
musx_images.display_points(converted_img, pts)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-139-dbea0acc84f7> in <module>
#       3 # print(vals)
#       4 data, pts = zip(*vals)
# ----> 5 musx_images.display_points(converted_img, pts)
#
# ~/Desktop/School/Music499/musx-images/musx_images.py in display_points(img, points, grayscale)
#     183     points_image.fill(255)
#     184
# --> 185     for (x, y) in points:
#     186         points_image[max(0, x - 25):min(img.shape[0] - 1, x + 25),max(0, y - 25):min(img.shape[1] - 1, y + 25), 0] = 0
#     187
#
# TypeError: cannot unpack non-iterable numpy.uint8 object

# %%
points = []
for _ in range(1000):
    points.append((int(musx.uniran() * converted_img.shape[0]), int(musx.uniran() * converted_img.shape[1])))

musx_images.display_points(converted_img, points)

# %%
[x for x in range(-1 * 3, 3 + 1)]
# Out:
# [-3, -2, -1, 0, 1, 2, 3]
